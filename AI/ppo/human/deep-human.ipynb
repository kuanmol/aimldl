# %%
import numpy as np
import torch
import torch.nn as nn
from torch.distributions import Normal
import gymnasium as gym  # or use `import gym` if not using Gymnasium

# Define the Actor-Critic network
class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU()
        )
        self.actor_mean = nn.Linear(256, action_dim)
        self.critic = nn.Linear(256, 1)
        self.log_std = nn.Parameter(torch.zeros(action_dim))

    def forward(self, x):
        x = self.net(x)
        mean = self.actor_mean(x)
        value = self.critic(x)
        return mean, value

# Initialize environment and model
env = gym.make("HumanoidStandup-v4", render_mode=None)  # or gym.make(...)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
model = ActorCritic(state_dim, action_dim)
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

# Hyperparameters
gamma = 0.99
lam = 0.95
clip_eps = 0.2
value_coef = 0.5
entropy_coef = 0.01
n_steps = 2048
ppo_epochs = 10
batch_size = 64

# Trackers
episode_rewards = []
episode_lengths = []
ep_reward = 0
ep_len = 0

# Training loop
for update in range(500):  # PPO updates
    state, _ = env.reset() if hasattr(env.reset(), "__len__") else (env.reset(), {})
    state = state.astype(np.float32)

    states, actions, logprobs, rewards, dones, values = [], [], [], [], [], []

    for step in range(n_steps):
        state_tensor = torch.from_numpy(state).float().unsqueeze(0)
        with torch.no_grad():
            mean, value = model(state_tensor)
        std = torch.exp(model.log_std)
        dist = Normal(mean, std)
        action = dist.sample()
        log_prob = dist.log_prob(action).sum(dim=1)
        action_np = action.cpu().numpy()[0]
        action_clamped = np.clip(action_np, env.action_space.low, env.action_space.high)

        # Step the environment
        result = env.step(action_clamped)
        if len(result) == 5:
            next_state, reward, terminated, truncated, _ = result
            done = terminated or truncated
        else:
            next_state, reward, done, _ = result

        # Store rollout
        states.append(state.copy())
        actions.append(action_np)
        logprobs.append(log_prob.item())
        rewards.append(np.clip(reward, -100.0, 100.0))
        dones.append(done)
        values.append(value.item())

        # Track episode reward
        ep_reward += reward
        ep_len += 1

        if done:
            episode_rewards.append(ep_reward)
            episode_lengths.append(ep_len)
            ep_reward = 0
            ep_len = 0
            state, _ = env.reset() if hasattr(env.reset(), "__len__") else (env.reset(), {})
            state = state.astype(np.float32)
        else:
            state = next_state.astype(np.float32)

    # Compute value of last state
    state_tensor = torch.from_numpy(state).float().unsqueeze(0)
    with torch.no_grad():
        _, last_value = model(state_tensor)
    last_value = last_value.item()

    # Convert to tensors
    states = torch.tensor(np.stack(states), dtype=torch.float32)
    actions = torch.tensor(np.stack(actions), dtype=torch.float32)
    old_logprobs = torch.tensor(logprobs, dtype=torch.float32)
    rewards = torch.tensor(rewards, dtype=torch.float32)
    dones = torch.tensor(dones, dtype=torch.float32)
    values = torch.tensor(values + [last_value], dtype=torch.float32)

    # Compute GAE advantages and returns
    returns = torch.zeros_like(rewards)
    advantages = torch.zeros_like(rewards)
    gae = 0.0
    for t in reversed(range(n_steps)):
        mask = 1.0 - dones[t]
        delta = rewards[t] + gamma * values[t + 1] * mask - values[t]
        gae = delta + gamma * lam * gae * mask
        advantages[t] = gae
        returns[t] = advantages[t] + values[t]

    advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

    # PPO update
    num_samples = n_steps
    for epoch in range(ppo_epochs):
        idxs = np.random.permutation(num_samples)
        for start in range(0, num_samples, batch_size):
            end = start + batch_size
            batch_idx = idxs[start:end]

            batch_states = states[batch_idx]
            batch_actions = actions[batch_idx]
            batch_old_logp = old_logprobs[batch_idx]
            batch_returns = returns[batch_idx]
            batch_adv = advantages[batch_idx]

            mean, value = model(batch_states)
            dist = Normal(mean, torch.exp(model.log_std))
            new_logp = dist.log_prob(batch_actions).sum(dim=1)
            entropy = dist.entropy().sum(dim=1).mean()

            ratio = (new_logp - batch_old_logp).exp()
            surr1 = ratio * batch_adv
            surr2 = torch.clamp(ratio, 1.0 - clip_eps, 1.0 + clip_eps) * batch_adv
            policy_loss = -torch.min(surr1, surr2).mean()

            value_pred = value.squeeze(1)
            value_loss = (value_pred - batch_returns).pow(2).mean()

            loss = policy_loss + value_coef * value_loss - entropy_coef * entropy

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    # Print progress
    if len(episode_rewards) >= 10:
        avg_reward = np.mean(episode_rewards[-10:])
        print(f"Update {update+1} | Episodes: {len(episode_rewards)} | Avg Reward (last 10): {avg_reward:.2f} | Max: {np.max(episode_rewards[-10:]):.1f} | Min: {np.min(episode_rewards[-10:]):.1f}")
    elif len(episode_rewards) > 0:
        print(f"Update {update+1} | Episodes: {len(episode_rewards)} | Latest Reward: {episode_rewards[-1]:.2f}")
    else:
        print(f"Update {update+1} | No completed episodes yet.")

# Save the trained model
torch.save(model.state_dict(), "ppo_humanoid_standup.pth")
print("✅ Model training complete and saved as 'ppo_humanoid_standup.pth'")
# Out:
# D:\Artificial\.venv\Lib\site-packages\gymnasium\envs\registration.py:519: DeprecationWarning: WARN: The environment HumanoidStandup-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Update 1 | Episodes: 2 | Latest Reward: 34836.85
# Update 2 | Episodes: 4 | Latest Reward: 49514.46
# Update 3 | Episodes: 6 | Latest Reward: 41788.51
# Update 4 | Episodes: 8 | Latest Reward: 39258.62
# Update 5 | Episodes: 10 | Avg Reward (last 10): 41351.11 | Max: 51115.3 | Min: 34456.7
# Update 6 | Episodes: 12 | Avg Reward (last 10): 43067.99 | Max: 51115.3 | Min: 37242.7
# Update 7 | Episodes: 14 | Avg Reward (last 10): 41762.56 | Max: 44744.5 | Min: 37242.7
# Update 8 | Episodes: 16 | Avg Reward (last 10): 44892.31 | Max: 59393.1 | Min: 37242.7
# Update 9 | Episodes: 18 | Avg Reward (last 10): 45061.91 | Max: 59393.1 | Min: 37242.7
# Update 10 | Episodes: 20 | Avg Reward (last 10): 45727.00 | Max: 59393.1 | Min: 40384.2
# Update 11 | Episodes: 22 | Avg Reward (last 10): 51221.10 | Max: 72091.5 | Min: 40384.2
# Update 12 | Episodes: 24 | Avg Reward (last 10): 63397.30 | Max: 106979.6 | Min: 40384.2
# Update 13 | Episodes: 26 | Avg Reward (last 10): 66462.69 | Max: 106979.6 | Min: 40384.2
# Update 14 | Episodes: 28 | Avg Reward (last 10): 66650.93 | Max: 106979.6 | Min: 39863.5
# Update 15 | Episodes: 30 | Avg Reward (last 10): 66447.71 | Max: 106979.6 | Min: 39618.6
# Update 45 | Episodes: 90 | Avg Reward (last 10): 59207.15 | Max: 84204.0 | Min: 45389.8
# Update 46 | Episodes: 92 | Avg Reward (last 10): 56794.22 | Max: 84204.0 | Min: 35118.4
# Update 47 | Episodes: 94 | Avg Reward (last 10): 47486.92 | Max: 67884.9 | Min: 35118.4
# Update 48 | Episodes: 96 | Avg Reward (last 10): 41596.48 | Max: 53010.1 | Min: 35095.0
# Update 49 | Episodes: 98 | Avg Reward (last 10): 39387.82 | Max: 53010.1 | Min: 35095.0
# Update 50 | Episodes: 100 | Avg Reward (last 10): 37487.99 | Max: 44413.6 | Min: 35095.0
# Update 51 | Episodes: 102 | Avg Reward (last 10): 37443.48 | Max: 44413.6 | Min: 35095.0
# Update 52 | Episodes: 104 | Avg Reward (last 10): 37462.98 | Max: 44413.6 | Min: 34975.3
# Update 53 | Episodes: 106 | Avg Reward (last 10): 39394.12 | Max: 50862.3 | Min: 34975.3
# Update 54 | Episodes: 108 | Avg Reward (last 10): 40500.87 | Max: 50862.3 | Min: 34975.3
# Update 55 | Episodes: 110 | Avg Reward (last 10): 40398.35 | Max: 50862.3 | Min: 34975.3
# Update 56 | Episodes: 112 | Avg Reward (last 10): 41428.67 | Max: 50862.3 | Min: 34975.3
# Update 57 | Episodes: 114 | Avg Reward (last 10): 42822.83 | Max: 50862.3 | Min: 40432.8
# Update 58 | Episodes: 116 | Avg Reward (last 10): 42187.67 | Max: 43805.1 | Min: 40432.8
# Update 59 | Episodes: 118 | Avg Reward (last 10): 43576.23 | Max: 55131.5 | Min: 40432.8
# Update 60 | Episodes: 120 | Avg Reward (last 10): 44990.37 | Max: 55621.0 | Min: 40723.4
# Update 61 | Episodes: 122 | Avg Reward (last 10): 60489.91 | Max: 119849.5 | Min: 41701.0
# Update 62 | Episodes: 124 | Avg Reward (last 10): 60406.83 | Max: 119849.5 | Min: 41701.0
# Update 63 | Episodes: 126 | Avg Reward (last 10): 75674.33 | Max: 120006.9 | Min: 41779.1
# Update 64 | Episodes: 128 | Avg Reward (last 10): 89814.18 | Max: 120572.7 | Min: 41779.1
# Update 65 | Episodes: 130 | Avg Reward (last 10): 103937.58 | Max: 120572.7 | Min: 41974.8
# Update 66 | Episodes: 132 | Avg Reward (last 10): 97342.39 | Max: 120572.7 | Min: 41974.8
# Update 67 | Episodes: 134 | Avg Reward (last 10): 112524.75 | Max: 120572.7 | Min: 53807.2
# Update 68 | Episodes: 136 | Avg Reward (last 10): 112428.56 | Max: 120572.7 | Min: 53807.2
# Update 69 | Episodes: 138 | Avg Reward (last 10): 112404.94 | Max: 120565.0 | Min: 53807.2
# Update 70 | Episodes: 140 | Avg Reward (last 10): 112425.21 | Max: 120678.9 | Min: 53807.2
# Update 71 | Episodes: 142 | Avg Reward (last 10): 103728.19 | Max: 120678.9 | Min: 41214.9
# Update 72 | Episodes: 144 | Avg Reward (last 10): 88461.88 | Max: 120678.9 | Min: 41214.9
# Update 73 | Episodes: 146 | Avg Reward (last 10): 74413.91 | Max: 120678.9 | Min: 41214.9
# Update 103 | Episodes: 206 | Avg Reward (last 10): 119354.27 | Max: 125043.0 | Min: 110598.8
# Update 104 | Episodes: 208 | Avg Reward (last 10): 119372.18 | Max: 125043.0 | Min: 110598.8
# Update 105 | Episodes: 210 | Avg Reward (last 10): 112769.71 | Max: 125043.0 | Min: 55928.2
# Update 106 | Episodes: 212 | Avg Reward (last 10): 111828.87 | Max: 122813.3 | Min: 55928.2
# Update 107 | Episodes: 214 | Avg Reward (last 10): 98934.92 | Max: 120900.6 | Min: 53710.9
# Update 108 | Episodes: 216 | Avg Reward (last 10): 90583.66 | Max: 120900.6 | Min: 53710.9
# Update 109 | Episodes: 218 | Avg Reward (last 10): 81664.34 | Max: 119688.3 | Min: 53710.9
# Update 110 | Episodes: 220 | Avg Reward (last 10): 87745.16 | Max: 120753.5 | Min: 53710.9
# Update 111 | Episodes: 222 | Avg Reward (last 10): 87623.09 | Max: 120753.5 | Min: 53710.9
# Update 112 | Episodes: 224 | Avg Reward (last 10): 87874.67 | Max: 120753.5 | Min: 47304.5
# Update 113 | Episodes: 226 | Avg Reward (last 10): 82681.42 | Max: 120753.5 | Min: 39330.2
# Update 114 | Episodes: 228 | Avg Reward (last 10): 76331.79 | Max: 120753.5 | Min: 39330.2
# Update 115 | Episodes: 230 | Avg Reward (last 10): 61472.40 | Max: 118909.2 | Min: 39330.2
# Update 116 | Episodes: 232 | Avg Reward (last 10): 62142.63 | Max: 123224.7 | Min: 39330.2
# Update 117 | Episodes: 234 | Avg Reward (last 10): 74387.56 | Max: 123224.7 | Min: 39330.2
# Update 118 | Episodes: 236 | Avg Reward (last 10): 88534.45 | Max: 123224.7 | Min: 39371.2
# Update 119 | Episodes: 238 | Avg Reward (last 10): 98975.10 | Max: 123224.7 | Min: 42141.7
# Update 120 | Episodes: 240 | Avg Reward (last 10): 113721.67 | Max: 123224.7 | Min: 75850.4
# Update 121 | Episodes: 242 | Avg Reward (last 10): 113100.20 | Max: 120468.1 | Min: 75850.4
# Update 122 | Episodes: 244 | Avg Reward (last 10): 108024.07 | Max: 120761.7 | Min: 64324.5
# Update 123 | Episodes: 246 | Avg Reward (last 10): 108378.72 | Max: 121108.6 | Min: 64324.5
# Update 124 | Episodes: 248 | Avg Reward (last 10): 113057.12 | Max: 121108.6 | Min: 64324.5
# Update 125 | Episodes: 250 | Avg Reward (last 10): 100407.57 | Max: 121108.6 | Min: 51831.7
# Update 126 | Episodes: 252 | Avg Reward (last 10): 90073.26 | Max: 121108.6 | Min: 51831.7
# Update 127 | Episodes: 254 | Avg Reward (last 10): 97390.93 | Max: 130842.6 | Min: 51831.7
# Update 128 | Episodes: 256 | Avg Reward (last 10): 99378.17 | Max: 131174.6 | Min: 51831.7
# Update 129 | Episodes: 258 | Avg Reward (last 10): 101464.29 | Max: 131603.8 | Min: 51831.7
# Update 130 | Episodes: 260 | Avg Reward (last 10): 116386.49 | Max: 131693.0 | Min: 55533.5
# Update 476 | Episodes: 952 | Avg Reward (last 10): 108703.73 | Max: 120334.3 | Min: 91614.7
# Update 477 | Episodes: 954 | Avg Reward (last 10): 109927.93 | Max: 120334.3 | Min: 98242.5
# Update 478 | Episodes: 956 | Avg Reward (last 10): 106305.08 | Max: 120334.3 | Min: 95007.5
# Update 479 | Episodes: 958 | Avg Reward (last 10): 105754.03 | Max: 120334.3 | Min: 95007.5
# Update 480 | Episodes: 960 | Avg Reward (last 10): 103325.21 | Max: 120334.3 | Min: 89135.7
# Update 481 | Episodes: 962 | Avg Reward (last 10): 102426.21 | Max: 113497.8 | Min: 89135.7
# Update 482 | Episodes: 964 | Avg Reward (last 10): 101391.11 | Max: 113497.8 | Min: 89135.7
# Update 483 | Episodes: 966 | Avg Reward (last 10): 103306.21 | Max: 113497.8 | Min: 89135.7
# Update 484 | Episodes: 968 | Avg Reward (last 10): 103672.05 | Max: 113497.8 | Min: 89135.7
# Update 485 | Episodes: 970 | Avg Reward (last 10): 104644.88 | Max: 113497.8 | Min: 94789.4
# Update 486 | Episodes: 972 | Avg Reward (last 10): 102286.81 | Max: 110699.1 | Min: 91243.1
# Update 487 | Episodes: 974 | Avg Reward (last 10): 101643.12 | Max: 106472.7 | Min: 91243.1
# Update 488 | Episodes: 976 | Avg Reward (last 10): 96147.81 | Max: 104677.8 | Min: 52292.1
# Update 489 | Episodes: 978 | Avg Reward (last 10): 95680.02 | Max: 104677.8 | Min: 52292.1
# Update 490 | Episodes: 980 | Avg Reward (last 10): 95574.67 | Max: 104858.7 | Min: 52292.1
# Update 491 | Episodes: 982 | Avg Reward (last 10): 94202.13 | Max: 104858.7 | Min: 52292.1
# Update 492 | Episodes: 984 | Avg Reward (last 10): 94677.04 | Max: 104858.7 | Min: 52292.1
# Update 493 | Episodes: 986 | Avg Reward (last 10): 95575.63 | Max: 104858.7 | Min: 68055.9
# Update 494 | Episodes: 988 | Avg Reward (last 10): 95424.21 | Max: 104858.7 | Min: 68055.9
# Update 495 | Episodes: 990 | Avg Reward (last 10): 92085.53 | Max: 104357.7 | Min: 68055.9
# Update 496 | Episodes: 992 | Avg Reward (last 10): 93066.00 | Max: 104357.7 | Min: 68055.9
# Update 497 | Episodes: 994 | Avg Reward (last 10): 91723.59 | Max: 101119.1 | Min: 68055.9
# Update 498 | Episodes: 996 | Avg Reward (last 10): 93441.66 | Max: 101119.1 | Min: 69629.2
# Update 499 | Episodes: 998 | Avg Reward (last 10): 93295.84 | Max: 105406.9 | Min: 69629.2
# Update 500 | Episodes: 1000 | Avg Reward (last 10): 94994.32 | Max: 105406.9 | Min: 88262.7
# ✅ Model training complete and saved as 'ppo_humanoid_standup.pth'

# %%
import numpy as np
import torch
from IPython.display import Video, display
import gymnasium as gym
import imageio

# Recreate model and load weights
model = ActorCritic(state_dim, action_dim)
model.load_state_dict(torch.load("ppo_humanoid_standup.pth"))
model.eval()

# Create environment with RGB array rendering
eval_env = gym.make("HumanoidStandup-v4", render_mode="rgb_array")
state, _ = eval_env.reset() if hasattr(eval_env.reset(), "__len__") else (eval_env.reset(), {})
state = state.astype(np.float32)

frames = []
done = False
while not done:
    state_tensor = torch.from_numpy(state).float().unsqueeze(0)
    with torch.no_grad():
        mean, _ = model(state_tensor)
    action = mean.cpu().numpy()[0]
    # Clamp action to valid range
    action = np.clip(action, eval_env.action_space.low, eval_env.action_space.high)

    result = eval_env.step(action)
    if len(result) == 5:  # Gymnasium API
        state, reward, terminated, truncated, _ = result
        done = terminated or truncated
    else:  # Gym API
        state, reward, done, _ = result
    state = state.astype(np.float32)

    # Render and store frame
    frame = eval_env.render()
    frames.append(frame)

eval_env.close()

# Save as MP4 video
video_filename = "humanoid_standup_slow.mp4"
imageio.mimsave(video_filename, frames, fps=30)

# Display video
display(Video(video_filename, embed=True, width=600))
# Out:
# D:\Artificial\.venv\Lib\site-packages\gymnasium\envs\registration.py:519: DeprecationWarning: WARN: The environment HumanoidStandup-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# <video controls  width="600" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## FAST Training

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.distributions import Normal
import gymnasium as gym

class ActorCriticSmall(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU()
        )
        self.actor_mean = nn.Linear(64, action_dim)
        self.critic = nn.Linear(64, 1)
        self.log_std = nn.Parameter(torch.zeros(action_dim))

    def forward(self, x):
        x = self.net(x)
        return self.actor_mean(x), self.critic(x)

env = gym.make("HumanoidStandup-v4", render_mode=None)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
model_fast = ActorCriticSmall(state_dim, action_dim)
optimizer = torch.optim.Adam(model_fast.parameters(), lr=3e-4)

gamma = 0.99
lam = 0.95
clip_eps = 0.2
value_coef = 0.5
entropy_coef = 0.01
n_steps = 1024
ppo_epochs = 4
batch_size = 64

for update in range(200):  # faster: fewer updates, ~200 updates * 1024 steps
    state, _ = env.reset() if hasattr(env.reset(), "__len__") else (env.reset(), {})
    state = state.astype(np.float32)
    states, actions, logprobs, rewards, dones, values = [], [], [], [], [], []

    for step in range(n_steps):
        state_tensor = torch.from_numpy(state).float().unsqueeze(0)
        with torch.no_grad():
            mean, value = model_fast(state_tensor)
        std = torch.exp(model_fast.log_std)
        dist = Normal(mean, std)
        action = dist.sample()
        log_prob = dist.log_prob(action).sum(dim=1)
        action_np = action.cpu().numpy()[0]
        action_clamped = np.clip(action_np, env.action_space.low, env.action_space.high)

        result = env.step(action_clamped)
        if len(result) == 5:
            next_state, reward, terminated, truncated, _ = result
            done = terminated or truncated
        else:
            next_state, reward, done, _ = result

        states.append(state.copy())
        actions.append(action_np)
        logprobs.append(log_prob.item())
        values.append(value.item())
        rewards.append(np.clip(reward, -100.0, 100.0))  # clip rewards
        dones.append(done)

        if done:
            state, _ = env.reset() if hasattr(env.reset(), "__len__") else (env.reset(), {})
            state = state.astype(np.float32)
        else:
            state = next_state.astype(np.float32)

    state_tensor = torch.from_numpy(state).float().unsqueeze(0)
    with torch.no_grad():
        _, last_value = model_fast(state_tensor)
    last_value = last_value.item()

    states = torch.tensor(np.stack(states), dtype=torch.float32)
    actions = torch.tensor(np.stack(actions), dtype=torch.float32)
    old_logprobs = torch.tensor(logprobs, dtype=torch.float32)
    values = torch.tensor(values + [last_value], dtype=torch.float32)
    rewards = torch.tensor(rewards, dtype=torch.float32)
    dones = torch.tensor(dones, dtype=torch.float32)

    returns = torch.zeros_like(rewards)
    advantages = torch.zeros_like(rewards)
    gae = 0.0
    for t in reversed(range(n_steps)):
        mask = 1.0 - dones[t]
        delta = rewards[t] + gamma * values[t+1] * mask - values[t]
        gae = delta + gamma * lam * gae * mask
        advantages[t] = gae
        returns[t] = advantages[t] + values[t]
    # (Optional: normalize advantages, skipped here for speed)
    advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

    num_samples = n_steps
    for epoch in range(ppo_epochs):
        idxs = np.random.permutation(num_samples)
        for start in range(0, num_samples, batch_size):
            end = start + batch_size
            batch_idx = idxs[start:end]

            batch_states = states[batch_idx]
            batch_actions = actions[batch_idx]
            batch_old_logp = old_logprobs[batch_idx]
            batch_returns = returns[batch_idx]
            batch_adv = advantages[batch_idx]

            mean, value = model_fast(batch_states)
            dist = Normal(mean, torch.exp(model_fast.log_std))
            new_logp = dist.log_prob(batch_actions).sum(dim=1)
            entropy = dist.entropy().sum(dim=1).mean()

            ratio = (new_logp - batch_old_logp).exp()
            surr1 = ratio * batch_adv
            surr2 = torch.clamp(ratio, 1.0 - clip_eps, 1.0 + clip_eps) * batch_adv
            policy_loss = -torch.min(surr1, surr2).mean()
            value_pred = value.squeeze(1)
            value_loss = (value_pred - batch_returns).pow(2).mean()
            loss = policy_loss + value_coef * value_loss - entropy_coef * entropy

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

torch.save(model_fast.state_dict(), "ppo_humanoid_fast.pth")
print("Fast model training complete and saved.")

# %% [markdown]
# # modulare

# %%
import os
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
from torch.distributions import Normal
from collections import deque

# Use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# === Actor Network ===
# A Gaussian policy network (MLP) mapping states to action means (and log_std).
class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_sizes=(256,256)):
        super().__init__()
        layers = []
        input_dim = state_dim
        # Build hidden layers
        for h in hidden_sizes:
            layers.append(nn.Linear(input_dim, h))
            layers.append(nn.ReLU())
            input_dim = h
        self.net = nn.Sequential(*layers)
        # Output layer for mean action
        self.mean_layer = nn.Linear(input_dim, action_dim)
        # Log-std parameter (one per action dimension)
        self.log_std = nn.Parameter(torch.zeros(action_dim) - 0.5)

    def forward(self, state):
        """Given a state tensor, return action mean and std."""
        x = self.net(state)
        mean = self.mean_layer(x)
        std = torch.exp(self.log_std)  # ensure positivity
        return mean, std

    def get_action(self, state):
        """Select an action by sampling from the policy (for training)."""
        mean, std = self.forward(state)
        dist = Normal(mean, std)
        action = dist.sample()
        log_prob = dist.log_prob(action).sum(dim=1)
        return action, log_prob

    def get_det_action(self, state):
        """Get deterministic action (mean) for evaluation."""
        mean, std = self.forward(state)
        return mean


# === Critic Network ===
# A value network (MLP) mapping states to scalar values.
class Critic(nn.Module):
    def __init__(self, state_dim, hidden_sizes=(256,256)):
        super().__init__()
        layers = []
        input_dim = state_dim
        # Build hidden layers
        for h in hidden_sizes:
            layers.append(nn.Linear(input_dim, h))
            layers.append(nn.ReLU())
            input_dim = h
        self.net = nn.Sequential(*layers)
        # Output layer for state-value
        self.value_layer = nn.Linear(input_dim, 1)

    def forward(self, state):
        """Given a state tensor, return state-value."""
        x = self.net(state)
        value = self.value_layer(x)
        return value


# === PPO Agent ===
class PPO:
    def __init__(self, state_dim, action_dim, args):
        """
        args: dictionary of hyperparameters, e.g.
          gamma, lam, clip_eps, epochs, batch_size, lr, ent_coef, vf_coef, max_grad_norm
        """
        # Actor and Critic networks
        self.actor = Actor(state_dim, action_dim).to(device)
        self.critic = Critic(state_dim).to(device)
        # Optimizers
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=args['lr'])
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=args['lr'])
        # PPO hyperparameters
        self.gamma = args.get('gamma', 0.99)
        self.lam = args.get('lam', 0.95)
        self.clip_eps = args.get('clip_eps', 0.2)
        self.ent_coef = args.get('ent_coef', 1e-3)
        self.vf_coef = args.get('vf_coef', 0.5)
        self.max_grad_norm = args.get('max_grad_norm', 0.5)
        self.n_epochs = args.get('n_epochs', 10)
        self.batch_size = args.get('batch_size', 64)

    def select_action(self, state):
        """Given a state (numpy), select action and compute logprob and value."""
        state = torch.tensor(state, dtype=torch.float32).to(device).unsqueeze(0)
        mean, std = self.actor(state)
        dist = Normal(mean, std)
        action = dist.sample()
        log_prob = dist.log_prob(action).sum(dim=1)
        value = self.critic(state)
        # Convert to numpy for environment
        return action.cpu().numpy()[0], log_prob.item(), value.item()

    def evaluate(self, states, actions):
        """
        For a batch of states and actions (torch tensors), compute log-probs,
        entropies, and state-values under the current policy.
        """
        mean, std = self.actor(states)
        dist = Normal(mean, std)
        log_probs = dist.log_prob(actions).sum(dim=1)
        entropy = dist.entropy().sum(dim=1)
        values = self.critic(states).squeeze(1)
        return log_probs, values, entropy

    def update(self, memory):
        """
        Update the policy and value networks using collected trajectories.
        memory is a dict with lists: states, actions, log_probs, values, rewards, dones.
        """
        # Convert memory to tensors
        states = torch.tensor(np.array(memory['states']), dtype=torch.float32).to(device)
        actions = torch.tensor(np.array(memory['actions']), dtype=torch.float32).to(device)
        old_log_probs = torch.tensor(memory['log_probs'], dtype=torch.float32).to(device)
        returns = []
        advantages = []
        # Convert to numpy for convenience
        rewards = memory['rewards']
        values = memory['values']
        dones = memory['dones']

        # Compute GAE advantages and returns
        gae = 0
        next_value = 0  # since episode ended
        for step in reversed(range(len(rewards))):
            mask = 1.0 - dones[step]
            delta = rewards[step] + self.gamma * next_value * mask - values[step]
            gae = delta + self.gamma * self.lam * mask * gae
            advantages.insert(0, gae)
            next_value = values[step]
        advantages = torch.tensor(advantages, dtype=torch.float32).to(device)
        returns = advantages + torch.tensor(values, dtype=torch.float32).to(device)

        # Normalize advantages
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        # Optimize policy for K epochs
        dataset_size = states.size(0)
        for _ in range(self.n_epochs):
            # Shuffle indices
            indices = np.arange(dataset_size)
            np.random.shuffle(indices)
            for start in range(0, dataset_size, self.batch_size):
                end = start + self.batch_size
                batch_idx = indices[start:end]
                batch_states = states[batch_idx]
                batch_actions = actions[batch_idx]
                batch_old_log_probs = old_log_probs[batch_idx]
                batch_returns = returns[batch_idx]
                batch_advantages = advantages[batch_idx]
                batch_old_values = torch.tensor(values, dtype=torch.float32).to(device)[batch_idx]

                # Evaluate current policy
                log_probs, new_values, entropy = self.evaluate(batch_states, batch_actions)
                # Policy (actor) loss
                ratios = torch.exp(log_probs - batch_old_log_probs)
                surr1 = ratios * batch_advantages
                surr2 = torch.clamp(ratios, 1 - self.clip_eps, 1 + self.clip_eps) * batch_advantages
                actor_loss = -torch.min(surr1, surr2).mean()

                # Value (critic) loss (with value clipping for stability)
                value_clipped = batch_old_values + torch.clamp(new_values - batch_old_values, -self.clip_eps, self.clip_eps)
                loss_unclipped = (new_values - batch_returns).pow(2)
                loss_clipped = (value_clipped - batch_returns).pow(2)
                critic_loss = 0.5 * torch.max(loss_unclipped, loss_clipped).mean()

                # Entropy (to encourage exploration)
                entropy_loss = entropy.mean()

                # Combined loss
                loss = actor_loss + self.vf_coef * critic_loss - self.ent_coef * entropy_loss

                # Backpropagate
                self.actor_optimizer.zero_grad()
                self.critic_optimizer.zero_grad()
                loss.backward()
                # Gradient clipping
                nn.utils.clip_grad_norm_(self.actor.parameters(), self.max_grad_norm)
                nn.utils.clip_grad_norm_(self.critic.parameters(), self.max_grad_norm)
                # Update parameters
                self.actor_optimizer.step()
                self.critic_optimizer.step()


def train(env_name="HumanoidStandup-v4", total_episodes=1000,
          eval_interval=20, reward_threshold=None):
    """
    Train PPO on the specified environment.
    Prints episode stats and saves the trained model.
    """
    # Hyperparameters (tuned for HumanoidStandup)
    args = dict(
        gamma=0.99, lam=0.9, clip_eps=0.2, ent_coef=1e-4,
        vf_coef=0.5, lr=2.5e-5, batch_size=64, n_epochs=10,
        max_grad_norm=0.5
    )
    # Create environment
    env = gym.make(env_name)
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.shape[0]
    agent = PPO(state_dim, action_dim, args)

    # For logging
    reward_history = []
    avg_rewards = []
    best_avg = -np.inf
    plateau_count = 0

    for ep in range(1, total_episodes+1):
        state, _ = env.reset()
        done = False
        ep_reward = 0
        max_height = 0.0
        # Memory for this episode
        memory = {'states': [], 'actions': [], 'log_probs': [], 'values': [], 'rewards': [], 'dones': []}

        # Generate one episode
        while not done:
            # Select action
            action, logp, value = agent.select_action(state)
            next_state, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated

            # Track highest z (height) from observation (state[0] holds height)
            max_height = max(max_height, state[0])

            # Store transition
            memory['states'].append(state)
            memory['actions'].append(action)
            memory['log_probs'].append(logp)
            memory['values'].append(value)
            memory['rewards'].append(reward)
            memory['dones'].append(done)

            state = next_state
            ep_reward += reward

        # End of episode: train on collected data
        agent.update(memory)

        # Logging
        reward_history.append(ep_reward)
        avg_reward = np.mean(reward_history[-20:])
        avg_rewards.append(avg_reward)

        print(f"Episode {ep:4d} | Reward: {ep_reward:8.2f} | "
              f"AvgReward(20): {avg_reward:8.2f} | MaxHeight: {max_height:6.2f}")

        # Early stopping if plateau or threshold
        if avg_reward > best_avg + 1e-3:
            best_avg = avg_reward
            plateau_count = 0
        else:
            plateau_count += 1

        if reward_threshold and avg_reward >= reward_threshold:
            print(f"Reached reward threshold of {reward_threshold}. Stopping early.")
            break
        if plateau_count >= 50:
            print(f"No improvement for 50 episodes (avg {best_avg:.2f}). Stopping early.")
            break

    # Save the trained model
    os.makedirs("models", exist_ok=True)
    torch.save({
        'actor_state_dict': agent.actor.state_dict(),
        'critic_state_dict': agent.critic.state_dict(),
    }, f"models/ppo_{env_name}.pth")
    print("Model saved.")

    env.close()
    return agent, reward_history, avg_rewards


def evaluate(agent, env_name="HumanoidStandup-v4", episodes=5, save_video=False):
    """
    Evaluate the trained agent for a number of episodes.
    Optionally save videos of the rollouts.
    """
    eval_env = gym.make(env_name, render_mode='rgb_array')
    if save_video:
        from gymnasium.wrappers import RecordVideo
        video_folder = "videos"
        eval_env = RecordVideo(eval_env, video_folder, episode_trigger=lambda x: True)
        print(f"Recording videos to {video_folder}/")

    total_reward = 0.0
    success_count = 0
    for ep in range(episodes):
        state, _ = eval_env.reset()
        done = False
        ep_reward = 0
        while not done:
            # Deterministic action (mean of policy)
            state_tensor = torch.tensor(state, dtype=torch.float32).to(device).unsqueeze(0)
            action = agent.actor.get_det_action(state_tensor).cpu().detach().numpy()[0]
            next_state, reward, terminated, truncated, info = eval_env.step(action)
            done = terminated or truncated
            state = next_state
            ep_reward += reward
        total_reward += ep_reward

        # Determine success (e.g., height above threshold)
        final_height = state[0]
        if final_height > 1.0:  # success threshold
            success_count += 1

        print(f"Eval Episode {ep+1}: Reward = {ep_reward:.2f}, FinalHeight = {final_height:.2f}")

    avg_reward = total_reward / episodes
    success_rate = success_count / episodes * 100
    print(f"Average Reward: {avg_reward:.2f} over {episodes} episodes")
    print(f"Success Rate (height>1.0): {success_rate:.1f}%")
    eval_env.close()


# === Main execution ===
if __name__ == "__main__":
    # Train the agent (prints logs)
    ppo_agent, rewards, avgs = train(env_name="HumanoidStandup-v4", total_episodes=500)

    # Evaluate the trained agent (run 5 episodes, save videos)
    evaluate(ppo_agent, env_name="HumanoidStandup-v4", episodes=5, save_video=True)
# Out:
# Episode    1 | Reward: 25430.04 | AvgReward(20): 25430.04 | MaxHeight:   0.18
# Episode    2 | Reward: 26130.28 | AvgReward(20): 25780.16 | MaxHeight:   0.17
# Episode    3 | Reward: 25825.52 | AvgReward(20): 25795.28 | MaxHeight:   0.21
# Episode    4 | Reward: 24764.91 | AvgReward(20): 25537.69 | MaxHeight:   0.16
# Episode    5 | Reward: 27621.27 | AvgReward(20): 25954.40 | MaxHeight:   0.18
# Episode    6 | Reward: 27168.43 | AvgReward(20): 26156.74 | MaxHeight:   0.19
# Episode    7 | Reward: 27851.01 | AvgReward(20): 26398.78 | MaxHeight:   0.21
# Episode    8 | Reward: 34430.27 | AvgReward(20): 27402.72 | MaxHeight:   0.20
# Episode    9 | Reward: 26737.66 | AvgReward(20): 27328.82 | MaxHeight:   0.17
# Episode   10 | Reward: 27503.65 | AvgReward(20): 27346.30 | MaxHeight:   0.18
# Episode   11 | Reward: 23863.92 | AvgReward(20): 27029.72 | MaxHeight:   0.17
# Episode   12 | Reward: 26210.93 | AvgReward(20): 26961.49 | MaxHeight:   0.16
# Episode   13 | Reward: 27385.43 | AvgReward(20): 26994.10 | MaxHeight:   0.18
# Episode   14 | Reward: 28840.93 | AvgReward(20): 27126.02 | MaxHeight:   0.17
# Episode   15 | Reward: 27051.94 | AvgReward(20): 27121.08 | MaxHeight:   0.17
# Episode   16 | Reward: 26104.68 | AvgReward(20): 27057.55 | MaxHeight:   0.20
# Episode   17 | Reward: 28818.21 | AvgReward(20): 27161.12 | MaxHeight:   0.15
# Episode   18 | Reward: 30027.90 | AvgReward(20): 27320.39 | MaxHeight:   0.20
# Episode   19 | Reward: 30482.72 | AvgReward(20): 27486.83 | MaxHeight:   0.19
# Episode   20 | Reward: 29613.81 | AvgReward(20): 27593.18 | MaxHeight:   0.20
# Episode   21 | Reward: 32983.58 | AvgReward(20): 27970.85 | MaxHeight:   0.19
# Episode   22 | Reward: 27031.80 | AvgReward(20): 28015.93 | MaxHeight:   0.17
# Episode   23 | Reward: 40847.25 | AvgReward(20): 28767.01 | MaxHeight:   0.22
# Episode   24 | Reward: 28392.93 | AvgReward(20): 28948.41 | MaxHeight:   0.20
# Episode   25 | Reward: 37119.08 | AvgReward(20): 29423.31 | MaxHeight:   0.21
# Episode   26 | Reward: 39268.59 | AvgReward(20): 30028.31 | MaxHeight:   0.19
# Episode   27 | Reward: 33229.62 | AvgReward(20): 30297.24 | MaxHeight:   0.21
# Episode   28 | Reward: 39626.88 | AvgReward(20): 30557.07 | MaxHeight:   0.21
# Episode   29 | Reward: 38190.71 | AvgReward(20): 31129.73 | MaxHeight:   0.22
# Episode   30 | Reward: 30947.22 | AvgReward(20): 31301.90 | MaxHeight:   0.22
# Episode   31 | Reward: 29835.60 | AvgReward(20): 31600.49 | MaxHeight:   0.25
# Episode   32 | Reward: 29288.95 | AvgReward(20): 31754.39 | MaxHeight:   0.21
# Episode   33 | Reward: 28739.09 | AvgReward(20): 31822.07 | MaxHeight:   0.20
# Episode   34 | Reward: 37365.50 | AvgReward(20): 32248.30 | MaxHeight:   0.24
# Episode   35 | Reward: 32342.36 | AvgReward(20): 32512.82 | MaxHeight:   0.22
# Episode   36 | Reward: 30466.51 | AvgReward(20): 32730.91 | MaxHeight:   0.18
# Episode   37 | Reward: 35963.93 | AvgReward(20): 33088.20 | MaxHeight:   0.22
# Episode   38 | Reward: 54032.35 | AvgReward(20): 34288.42 | MaxHeight:   0.28
# Episode   39 | Reward: 56485.70 | AvgReward(20): 35588.57 | MaxHeight:   0.26
# Episode   40 | Reward: 31241.83 | AvgReward(20): 35669.97 | MaxHeight:   0.23
# Episode   41 | Reward: 41742.14 | AvgReward(20): 36107.90 | MaxHeight:   0.30
# Episode   42 | Reward: 66262.31 | AvgReward(20): 38069.43 | MaxHeight:   0.27
# Episode   43 | Reward: 33760.36 | AvgReward(20): 37715.08 | MaxHeight:   0.20
# Episode   44 | Reward: 31148.71 | AvgReward(20): 37852.87 | MaxHeight:   0.22
# Episode   45 | Reward: 26434.32 | AvgReward(20): 37318.63 | MaxHeight:   0.20
# Episode   46 | Reward: 36585.18 | AvgReward(20): 37184.46 | MaxHeight:   0.21
# Episode   47 | Reward: 37890.94 | AvgReward(20): 37417.53 | MaxHeight:   0.24
# Episode   48 | Reward: 36480.19 | AvgReward(20): 37260.19 | MaxHeight:   0.23
# Episode   49 | Reward: 36614.12 | AvgReward(20): 37181.37 | MaxHeight:   0.26
# Episode   50 | Reward: 38240.86 | AvgReward(20): 37546.05 | MaxHeight:   0.24
# Episode   51 | Reward: 55201.18 | AvgReward(20): 38814.33 | MaxHeight:   0.24
# Episode   52 | Reward: 52288.32 | AvgReward(20): 39964.30 | MaxHeight:   0.24
# Episode   53 | Reward: 38659.45 | AvgReward(20): 40460.31 | MaxHeight:   0.26
# Episode   54 | Reward: 32920.89 | AvgReward(20): 40238.08 | MaxHeight:   0.20
# Episode   55 | Reward: 66233.38 | AvgReward(20): 41932.63 | MaxHeight:   0.28
# Episode   56 | Reward: 55218.98 | AvgReward(20): 43170.26 | MaxHeight:   0.24
# Episode   57 | Reward: 52925.17 | AvgReward(20): 44018.32 | MaxHeight:   0.25
# Episode   58 | Reward: 66188.85 | AvgReward(20): 44626.14 | MaxHeight:   0.27
# Episode   59 | Reward: 43810.49 | AvgReward(20): 43992.38 | MaxHeight:   0.21
# Episode   60 | Reward: 44717.51 | AvgReward(20): 44666.17 | MaxHeight:   0.27
# Episode   61 | Reward: 32813.44 | AvgReward(20): 44219.73 | MaxHeight:   0.17
# Episode   62 | Reward: 55838.70 | AvgReward(20): 43698.55 | MaxHeight:   0.25
# Episode   63 | Reward: 66856.27 | AvgReward(20): 45353.35 | MaxHeight:   0.28
# Episode   64 | Reward: 32254.22 | AvgReward(20): 45408.62 | MaxHeight:   0.24
# Episode   65 | Reward: 63709.23 | AvgReward(20): 47272.37 | MaxHeight:   0.29
# Episode   66 | Reward: 37944.57 | AvgReward(20): 47340.34 | MaxHeight:   0.26
# Episode   67 | Reward: 33129.19 | AvgReward(20): 47102.25 | MaxHeight:   0.25
# Episode   68 | Reward: 32980.28 | AvgReward(20): 46927.26 | MaxHeight:   0.19
# Episode   69 | Reward: 28488.69 | AvgReward(20): 46520.98 | MaxHeight:   0.19
# Episode   70 | Reward: 35683.98 | AvgReward(20): 46393.14 | MaxHeight:   0.29
# Episode   71 | Reward: 32482.69 | AvgReward(20): 45257.22 | MaxHeight:   0.19
# Episode   72 | Reward: 28932.88 | AvgReward(20): 44089.44 | MaxHeight:   0.20
# Episode   73 | Reward: 32364.10 | AvgReward(20): 43774.68 | MaxHeight:   0.19
# Episode   74 | Reward: 37588.06 | AvgReward(20): 44008.03 | MaxHeight:   0.22
# Episode   75 | Reward: 67013.57 | AvgReward(20): 44047.04 | MaxHeight:   0.26
# Episode   76 | Reward: 27730.99 | AvgReward(20): 42672.64 | MaxHeight:   0.18
# Episode   77 | Reward: 33073.90 | AvgReward(20): 41680.08 | MaxHeight:   0.20
# Episode   78 | Reward: 41283.89 | AvgReward(20): 40434.83 | MaxHeight:   0.26
# Episode   79 | Reward: 31260.36 | AvgReward(20): 39807.33 | MaxHeight:   0.20
# Episode   80 | Reward: 32990.46 | AvgReward(20): 39220.97 | MaxHeight:   0.23
# Episode   81 | Reward: 51488.75 | AvgReward(20): 40154.74 | MaxHeight:   0.33
# Episode   82 | Reward: 29700.91 | AvgReward(20): 38847.85 | MaxHeight:   0.18
# Episode   83 | Reward: 56436.46 | AvgReward(20): 38326.86 | MaxHeight:   0.26
# Episode   84 | Reward: 51963.26 | AvgReward(20): 39312.31 | MaxHeight:   0.25
# Episode   85 | Reward: 32541.38 | AvgReward(20): 37753.92 | MaxHeight:   0.19
# Episode   86 | Reward: 30249.08 | AvgReward(20): 37369.14 | MaxHeight:   0.16
# Episode   87 | Reward: 32636.81 | AvgReward(20): 37344.53 | MaxHeight:   0.22
# Episode   88 | Reward: 35324.84 | AvgReward(20): 37461.75 | MaxHeight:   0.19
# Episode   89 | Reward: 42219.68 | AvgReward(20): 38148.30 | MaxHeight:   0.25
# Episode   90 | Reward: 63539.65 | AvgReward(20): 39541.09 | MaxHeight:   0.26
# Episode   91 | Reward: 31239.05 | AvgReward(20): 39478.90 | MaxHeight:   0.23
# Episode   92 | Reward: 65403.46 | AvgReward(20): 41302.43 | MaxHeight:   0.29
# Episode   93 | Reward: 35463.39 | AvgReward(20): 41457.40 | MaxHeight:   0.29
# Episode   94 | Reward: 63415.33 | AvgReward(20): 42748.76 | MaxHeight:   0.30
# Episode   95 | Reward: 59777.62 | AvgReward(20): 42386.96 | MaxHeight:   0.26
# Episode   96 | Reward: 63080.72 | AvgReward(20): 44154.45 | MaxHeight:   0.27
# Episode   97 | Reward: 64430.41 | AvgReward(20): 45722.28 | MaxHeight:   0.26
# Episode   98 | Reward: 61957.37 | AvgReward(20): 46755.95 | MaxHeight:   0.25
# Episode   99 | Reward: 65488.84 | AvgReward(20): 48467.37 | MaxHeight:   0.26
# Episode  100 | Reward: 65941.30 | AvgReward(20): 50114.92 | MaxHeight:   0.28
# Episode  101 | Reward: 59252.09 | AvgReward(20): 50503.08 | MaxHeight:   0.25
# Episode  102 | Reward: 50282.30 | AvgReward(20): 51532.15 | MaxHeight:   0.26
# Episode  103 | Reward: 47339.46 | AvgReward(20): 51077.30 | MaxHeight:   0.24
# Episode  104 | Reward: 57463.72 | AvgReward(20): 51352.33 | MaxHeight:   0.25
# Episode  105 | Reward: 63592.01 | AvgReward(20): 52904.86 | MaxHeight:   0.26
# Episode  106 | Reward: 53368.94 | AvgReward(20): 54060.85 | MaxHeight:   0.26
# Episode  107 | Reward: 49942.11 | AvgReward(20): 54926.11 | MaxHeight:   0.27
# Episode  108 | Reward: 48756.29 | AvgReward(20): 55597.69 | MaxHeight:   0.33
# Episode  109 | Reward: 52466.13 | AvgReward(20): 56110.01 | MaxHeight:   0.26
# Episode  110 | Reward: 38897.97 | AvgReward(20): 54877.93 | MaxHeight:   0.26
# Episode  111 | Reward: 44259.48 | AvgReward(20): 55528.95 | MaxHeight:   0.26
# Episode  112 | Reward: 48710.89 | AvgReward(20): 54694.32 | MaxHeight:   0.26
# Episode  113 | Reward: 49917.12 | AvgReward(20): 55417.00 | MaxHeight:   0.26
# Episode  114 | Reward: 39869.03 | AvgReward(20): 54239.69 | MaxHeight:   0.25
# Episode  115 | Reward: 53549.70 | AvgReward(20): 53928.29 | MaxHeight:   0.25
# Episode  116 | Reward: 39315.48 | AvgReward(20): 52740.03 | MaxHeight:   0.26
# Episode  117 | Reward: 35373.66 | AvgReward(20): 51287.19 | MaxHeight:   0.24
# Episode  118 | Reward: 36231.15 | AvgReward(20): 50000.88 | MaxHeight:   0.28
# Episode  119 | Reward: 48995.11 | AvgReward(20): 49176.20 | MaxHeight:   0.25
# Episode  120 | Reward: 31053.72 | AvgReward(20): 47431.82 | MaxHeight:   0.23
# Episode  121 | Reward: 61058.36 | AvgReward(20): 47522.13 | MaxHeight:   0.26
# Episode  122 | Reward: 27404.50 | AvgReward(20): 46378.24 | MaxHeight:   0.21
# Episode  123 | Reward: 47539.74 | AvgReward(20): 46388.26 | MaxHeight:   0.26
# Episode  124 | Reward: 47715.28 | AvgReward(20): 45900.83 | MaxHeight:   0.28
# Episode  125 | Reward: 44865.04 | AvgReward(20): 44964.49 | MaxHeight:   0.27
# Episode  126 | Reward: 51604.49 | AvgReward(20): 44876.26 | MaxHeight:   0.25
# Episode  127 | Reward: 49389.53 | AvgReward(20): 44848.63 | MaxHeight:   0.26
# Episode  128 | Reward: 53150.87 | AvgReward(20): 45068.36 | MaxHeight:   0.25
# Episode  129 | Reward: 51152.61 | AvgReward(20): 45002.69 | MaxHeight:   0.25
# Episode  130 | Reward: 58468.34 | AvgReward(20): 45981.21 | MaxHeight:   0.28
# Episode  131 | Reward: 43792.06 | AvgReward(20): 45957.83 | MaxHeight:   0.26
# Episode  132 | Reward: 47989.81 | AvgReward(20): 45921.78 | MaxHeight:   0.25
# Episode  133 | Reward: 51571.50 | AvgReward(20): 46004.50 | MaxHeight:   0.27
# Episode  134 | Reward: 37025.83 | AvgReward(20): 45862.34 | MaxHeight:   0.23
# Episode  135 | Reward: 53093.58 | AvgReward(20): 45839.53 | MaxHeight:   0.26
# Episode  136 | Reward: 45684.14 | AvgReward(20): 46157.97 | MaxHeight:   0.28
# Episode  137 | Reward: 60114.98 | AvgReward(20): 47395.03 | MaxHeight:   0.28
# Episode  138 | Reward: 56232.08 | AvgReward(20): 48395.08 | MaxHeight:   0.26
# Episode  139 | Reward: 60590.29 | AvgReward(20): 48974.84 | MaxHeight:   0.26
# Episode  140 | Reward: 62685.70 | AvgReward(20): 50556.44 | MaxHeight:   0.27
# Episode  141 | Reward: 66988.88 | AvgReward(20): 50852.96 | MaxHeight:   0.33
# Episode  142 | Reward: 55240.35 | AvgReward(20): 52244.76 | MaxHeight:   0.30
# Episode  143 | Reward: 63999.62 | AvgReward(20): 53067.75 | MaxHeight:   0.26
# Episode  144 | Reward: 66454.44 | AvgReward(20): 54004.71 | MaxHeight:   0.28
# Episode  145 | Reward: 59334.38 | AvgReward(20): 54728.17 | MaxHeight:   0.27
# Episode  146 | Reward: 53909.73 | AvgReward(20): 54843.44 | MaxHeight:   0.27
# Episode  147 | Reward: 54416.83 | AvgReward(20): 55094.80 | MaxHeight:   0.27
# Episode  148 | Reward: 62768.06 | AvgReward(20): 55575.66 | MaxHeight:   0.27
# Episode  149 | Reward: 59680.78 | AvgReward(20): 56002.07 | MaxHeight:   0.29
# Episode  150 | Reward: 63357.27 | AvgReward(20): 56246.51 | MaxHeight:   0.27
# Episode  151 | Reward: 60604.59 | AvgReward(20): 57087.14 | MaxHeight:   0.28
# Episode  152 | Reward: 56148.00 | AvgReward(20): 57495.05 | MaxHeight:   0.27
# Episode  153 | Reward: 65124.16 | AvgReward(20): 58172.68 | MaxHeight:   0.27
# Episode  154 | Reward: 65518.83 | AvgReward(20): 59597.33 | MaxHeight:   0.28
# Episode  155 | Reward: 64465.66 | AvgReward(20): 60165.94 | MaxHeight:   0.29
# Episode  156 | Reward: 58142.17 | AvgReward(20): 60788.84 | MaxHeight:   0.27
# Episode  157 | Reward: 54981.05 | AvgReward(20): 60532.14 | MaxHeight:   0.29
# Episode  158 | Reward: 55688.31 | AvgReward(20): 60504.95 | MaxHeight:   0.31
# Episode  159 | Reward: 58153.40 | AvgReward(20): 60383.11 | MaxHeight:   0.26
# Episode  160 | Reward: 63530.79 | AvgReward(20): 60425.36 | MaxHeight:   0.29
# Episode  161 | Reward: 43787.91 | AvgReward(20): 59265.32 | MaxHeight:   0.28
# Episode  162 | Reward: 69124.62 | AvgReward(20): 59959.53 | MaxHeight:   0.27
# Episode  163 | Reward: 66111.04 | AvgReward(20): 60065.10 | MaxHeight:   0.28
# Episode  164 | Reward: 60262.99 | AvgReward(20): 59755.53 | MaxHeight:   0.27
# Episode  165 | Reward: 48990.32 | AvgReward(20): 59238.33 | MaxHeight:   0.26
# Episode  166 | Reward: 68683.12 | AvgReward(20): 59976.99 | MaxHeight:   0.29
# Episode  167 | Reward: 62648.41 | AvgReward(20): 60388.57 | MaxHeight:   0.30
# Episode  168 | Reward: 38542.95 | AvgReward(20): 59177.32 | MaxHeight:   0.27
# Episode  169 | Reward: 42352.64 | AvgReward(20): 58310.91 | MaxHeight:   0.27
# Episode  170 | Reward: 64875.30 | AvgReward(20): 58386.81 | MaxHeight:   0.30
# Episode  171 | Reward: 45265.96 | AvgReward(20): 57619.88 | MaxHeight:   0.25
# Episode  172 | Reward: 56913.80 | AvgReward(20): 57658.17 | MaxHeight:   0.28
# Episode  173 | Reward: 49015.56 | AvgReward(20): 56852.74 | MaxHeight:   0.27
# Episode  174 | Reward: 56553.82 | AvgReward(20): 56404.49 | MaxHeight:   0.28
# Episode  175 | Reward: 63396.92 | AvgReward(20): 56351.05 | MaxHeight:   0.28
# Episode  176 | Reward: 65594.09 | AvgReward(20): 56723.65 | MaxHeight:   0.28
# Episode  177 | Reward: 53277.46 | AvgReward(20): 56638.47 | MaxHeight:   0.27
# Episode  178 | Reward: 42010.13 | AvgReward(20): 55954.56 | MaxHeight:   0.27
# Episode  179 | Reward: 59730.12 | AvgReward(20): 56033.40 | MaxHeight:   0.29
# Episode  180 | Reward: 68430.23 | AvgReward(20): 56278.37 | MaxHeight:   0.30
# Episode  181 | Reward: 62325.42 | AvgReward(20): 57205.24 | MaxHeight:   0.27
# Episode  182 | Reward: 51457.95 | AvgReward(20): 56321.91 | MaxHeight:   0.27
# Episode  183 | Reward: 62100.21 | AvgReward(20): 56121.37 | MaxHeight:   0.28
# Episode  184 | Reward: 58169.58 | AvgReward(20): 56016.70 | MaxHeight:   0.28
# Episode  185 | Reward: 49868.95 | AvgReward(20): 56060.63 | MaxHeight:   0.31
# Episode  186 | Reward: 62899.81 | AvgReward(20): 55771.47 | MaxHeight:   0.29
# Episode  187 | Reward: 61274.13 | AvgReward(20): 55702.75 | MaxHeight:   0.27
# Episode  188 | Reward: 59934.74 | AvgReward(20): 56772.34 | MaxHeight:   0.27
# Episode  189 | Reward: 67638.56 | AvgReward(20): 58036.64 | MaxHeight:   0.28
# Episode  190 | Reward: 53660.13 | AvgReward(20): 57475.88 | MaxHeight:   0.28
# Episode  191 | Reward: 44591.56 | AvgReward(20): 57442.16 | MaxHeight:   0.26
# Episode  192 | Reward: 67414.25 | AvgReward(20): 57967.18 | MaxHeight:   0.27
# Episode  193 | Reward: 55533.85 | AvgReward(20): 58293.10 | MaxHeight:   0.28
# Episode  194 | Reward: 61597.77 | AvgReward(20): 58545.29 | MaxHeight:   0.28
# Episode  195 | Reward: 45551.15 | AvgReward(20): 57653.00 | MaxHeight:   0.25
# Episode  196 | Reward: 46382.90 | AvgReward(20): 56692.44 | MaxHeight:   0.28
# Episode  197 | Reward: 57733.26 | AvgReward(20): 56915.23 | MaxHeight:   0.28
# Episode  198 | Reward: 53657.30 | AvgReward(20): 57497.59 | MaxHeight:   0.29
# Episode  199 | Reward: 56588.20 | AvgReward(20): 57340.50 | MaxHeight:   0.26
# Episode  200 | Reward: 37643.87 | AvgReward(20): 55801.18 | MaxHeight:   0.25
# Episode  201 | Reward: 57264.42 | AvgReward(20): 55548.13 | MaxHeight:   0.28
# Episode  202 | Reward: 58296.27 | AvgReward(20): 55890.05 | MaxHeight:   0.27
# Episode  203 | Reward: 52478.26 | AvgReward(20): 55408.95 | MaxHeight:   0.28
# Episode  204 | Reward: 58966.61 | AvgReward(20): 55448.80 | MaxHeight:   0.28
# Episode  205 | Reward: 62630.04 | AvgReward(20): 56086.85 | MaxHeight:   0.27
# Episode  206 | Reward: 55036.08 | AvgReward(20): 55693.67 | MaxHeight:   0.26
# No improvement for 50 episodes (avg 60788.84). Stopping early.
# Model saved.
# Recording videos to videos/
# Eval Episode 1: Reward = 52772.69, FinalHeight = 0.24
# Eval Episode 2: Reward = 59309.25, FinalHeight = 0.25
# Eval Episode 3: Reward = 60694.33, FinalHeight = 0.25
# Eval Episode 4: Reward = 60575.41, FinalHeight = 0.20
# Eval Episode 5: Reward = 65233.65, FinalHeight = 0.25
# Average Reward: 59717.07 over 5 episodes
# Success Rate (height>1.0): 0.0%
